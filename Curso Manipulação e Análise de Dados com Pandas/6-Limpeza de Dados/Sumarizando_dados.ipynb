# %%
import pandas as pd
import numpy as np

# %%
datas = pd.date_range ('20200101', periods = 6)

df = pd.DataFrame(np.random.randn(6, 4), index=datas, columns = ['Var_A', 'Var_B', 'Var_C', 'Var_D'])

# %%
df2 = pd.DataFrame ({'A' : 1.,
                    'B' : pd.Timestamp ('20130102'),
                    'C' : pd.Series(1, index=list(range(4)), dtype='float32'),
                    'D' : np.array([3] * 4, dtype='int32'),
                    'E' : pd.Categorical(['test', 'train', 'test', 'train']),
                    'F' : 'Python'})

# %%
df
# Out:
#                Var_A     Var_B     Var_C     Var_D
# 2020-01-01  0.835801  1.694427  1.198966  0.306099
# 2020-01-02 -0.559136 -1.104962  0.652548  0.118525
# 2020-01-03 -1.268674  1.056579  1.005314 -0.839715
# 2020-01-04  1.342434 -1.285844  0.734551 -1.108644
# 2020-01-05  1.339307 -0.937465 -0.132258  0.080671
# 2020-01-06 -0.021584 -0.681406 -1.119550  0.743998

# %%
df.shape
# Out:
# (6, 4)

# %%
df.dtypes
# Out:
# Var_A    float64
# Var_B    float64
# Var_C    float64
# Var_D    float64
# dtype: object

# %%
df
# Out:
#                Var_A     Var_B     Var_C     Var_D
# 2020-01-01  0.835801  1.694427  1.198966  0.306099
# 2020-01-02 -0.559136 -1.104962  0.652548  0.118525
# 2020-01-03 -1.268674  1.056579  1.005314 -0.839715
# 2020-01-04  1.342434 -1.285844  0.734551 -1.108644
# 2020-01-05  1.339307 -0.937465 -0.132258  0.080671
# 2020-01-06 -0.021584 -0.681406 -1.119550  0.743998

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df2
# Out:
#      A          B    C  D      E       F
# 0  1.0 2013-01-02  1.0  3   test  Python
# 1  1.0 2013-01-02  1.0  3  train  Python
# 2  1.0 2013-01-02  1.0  3   test  Python
# 3  1.0 2013-01-02  1.0  3  train  Python

# %%
df2.describe()
# Out:
#          A    C    D
# count  4.0  4.0  4.0
# mean   1.0  1.0  3.0
# std    0.0  0.0  0.0
# min    1.0  1.0  3.0
# 25%    1.0  1.0  3.0
# 50%    1.0  1.0  3.0
# 75%    1.0  1.0  3.0
# max    1.0  1.0  3.0

# %%
 df1 = df.reindex(index=datas[0:4], columns=list(df.columns) + ['Var_E'])

# %%
df1
# Out:
#                Var_A     Var_B     Var_C     Var_D  Var_E
# 2020-01-01  0.835801  1.694427  1.198966  0.306099    NaN
# 2020-01-02 -0.559136 -1.104962  0.652548  0.118525    NaN
# 2020-01-03 -1.268674  1.056579  1.005314 -0.839715    NaN
# 2020-01-04  1.342434 -1.285844  0.734551 -1.108644    NaN

# %%
df1.loc[datas[0]:datas[1], 'Var_E'] = 77

# %%
df1
# Out:
#                Var_A     Var_B     Var_C     Var_D  Var_E
# 2020-01-01  0.835801  1.694427  1.198966  0.306099   77.0
# 2020-01-02 -0.559136 -1.104962  0.652548  0.118525   77.0
# 2020-01-03 -1.268674  1.056579  1.005314 -0.839715    NaN
# 2020-01-04  1.342434 -1.285844  0.734551 -1.108644    NaN

# %%
df1.describe()
# Out:
#           Var_A     Var_B     Var_C     Var_D  Var_E
# count  4.000000  4.000000  4.000000  4.000000    2.0
# mean   0.087606  0.090050  0.897845 -0.380934   77.0
# std    1.209980  1.508790  0.251037  0.697977    0.0
# min   -1.268674 -1.285844  0.652548 -1.108644   77.0
# 25%   -0.736520 -1.150182  0.714050 -0.906947   77.0
# 50%    0.138333 -0.024191  0.869933 -0.360595   77.0
# 75%    0.962459  1.216041  1.053727  0.165419   77.0
# max    1.342434  1.694427  1.198966  0.306099   77.0
