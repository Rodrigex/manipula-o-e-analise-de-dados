# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-39f510d45dca> in <module>()
# ----> 1 plt.style.use()
#
# TypeError: use() missing 1 required positional argument: 'style'

# %%
plt.rcParams['figure.figsize'] = (20, 10)

# %%
d = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Dados-Aulas-Udemy/Titanic/titanic_train.csv')

# %%
d.head(10)
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
# 5            6         0       3  ...   8.4583   NaN         Q
# 6            7         0       1  ...  51.8625   E46         S
# 7            8         0       3  ...  21.0750   NaN         S
# 8            9         1       3  ...  11.1333   NaN         S
# 9           10         1       2  ...  30.0708   NaN         C
#
# [10 rows x 12 columns]

# %%
d.shape
# Out:
# (891, 12)

# %%
plt.plot(d.Age, '*-b')
plt.title('Informações das Idades dos Passageiros')
plt.xlabel('Passageiro', size=14)
plt.ylabel('Idade', size=16)
plt.show()

# %%
 d.Age.plot()
 plt.show()

# %%
d.plot()
plt.show()

# %%
 #Scatter plot

# %%
d.head(2)
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
#
# [2 rows x 12 columns]

# %%
plt.scatter(d.PassengerId, d.Age, color='pink', marker='*')
plt.show()

# %%
#histogramas

# %%
d.Age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
d.Age.hist()
plt.xlabel('idade', size=15)
plt.ylabel('Frequência Observada')
plt.savefig('nome_fig.png')
plt.show()

# %%
plt.savefig('nome_fig.png')

# %%
plt.savefig('nome_fig.png')

# %%
plt.savefig('nome_fig.png')
