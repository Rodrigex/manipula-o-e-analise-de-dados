# %%
import pandas as pd
import numpy as np

# %%
datas = pd.date_range('20200101', periods=6)
df = pd.DataFrame(np.random.randn(6, 4), index=datas, columns= ['Var_A', 'Var_B', 'Var_C', 'Var_D'])
df
# Out:
#                Var_A     Var_B     Var_C     Var_D
# 2020-01-01  0.430029 -1.612342 -0.658650  0.472781
# 2020-01-02  1.552427  0.094104  0.401921  1.435308
# 2020-01-03  1.160763  0.957819  0.195212 -0.886667
# 2020-01-04  1.672639  0.655101  0.546191 -0.724269
# 2020-01-05  1.017403  0.450037  0.093415  0.359668
# 2020-01-06  1.521068  0.010014  1.235633 -0.546220

# %%
dft = df.T
dft
# Out:
#        2020-01-01  2020-01-02  2020-01-03  2020-01-04  2020-01-05  2020-01-06
# Var_A    0.430029    1.552427    1.160763    1.672639    1.017403    1.521068
# Var_B   -1.612342    0.094104    0.957819    0.655101    0.450037    0.010014
# Var_C   -0.658650    0.401921    0.195212    0.546191    0.093415    1.235633
# Var_D    0.472781    1.435308   -0.886667   -0.724269    0.359668   -0.546220

# %%
df.shape
# Out:
# (6, 4)

# %%
 dft.values
# Out:
# array([[ 0.43002906,  1.55242735,  1.16076274,  1.67263921,  1.01740346,
#          1.52106759],
#        [-1.61234212,  0.094104  ,  0.95781906,  0.6551011 ,  0.45003657,
#          0.01001431],
#        [-0.65864981,  0.40192079,  0.19521184,  0.54619099,  0.09341525,
#          1.23563255],
#        [ 0.47278094,  1.43530781, -0.88666657, -0.72426877,  0.35966809,
#         -0.54621962]])

# %%
v = dft.values

# %%
v.reshape((2,12))
# Out:
# array([[ 0.43002906,  1.55242735,  1.16076274,  1.67263921,  1.01740346,
#          1.52106759, -1.61234212,  0.094104  ,  0.95781906,  0.6551011 ,
#          0.45003657,  0.01001431],
#        [-0.65864981,  0.40192079,  0.19521184,  0.54619099,  0.09341525,
#          1.23563255,  0.47278094,  1.43530781, -0.88666657, -0.72426877,
#          0.35966809, -0.54621962]])
