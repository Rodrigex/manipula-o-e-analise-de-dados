# %%
import pandas as pd
import numpy as np

# %%
dias = pd.date_range(start='20190101', periods=12)

# %%
dias
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-05', '2019-01-06', '2019-01-07', '2019-01-08',
#                '2019-01-09', '2019-01-10', '2019-01-11', '2019-01-12'],
#               dtype='datetime64[ns]', freq='D')

# %%
Pessoa = ['George', 'Victor', 'Lucas']

# %%
np.random.choice(Pessoa)
# Out:
# 'George'

# %%
Nome = []
Gasto = []
for i in range(12):
  Nome.append(np.random.choice(Pessoa))
  Gasto.append( np.round(np.random.rand()*100,2))
Nome
# Out:
# ['Victor',
#  'Lucas',
#  'George',
#  'Lucas',
#  'Victor',
#  'George',
#  'Lucas',
#  'George',
#  'George',
#  'George',
#  'Victor',
#  'Lucas']

# %%
Gasto
# Out:
# [1.99,
#  99.0,
#  8.83,
#  41.42,
#  87.34,
#  18.51,
#  3.56,
#  56.06,
#  12.25,
#  47.41,
#  58.66,
#  53.35]

# %%
df = pd.DataFrame ({'Dia' : dias, 'Nome' :Nome, 'Gasto': Gasto})
df
# Out:
#           Dia    Nome  Gasto
# 0  2019-01-01  Victor   1.99
# 1  2019-01-02   Lucas  99.00
# 2  2019-01-03  George   8.83
# 3  2019-01-04   Lucas  41.42
# 4  2019-01-05  Victor  87.34
# 5  2019-01-06  George  18.51
# 6  2019-01-07   Lucas   3.56
# 7  2019-01-08  George  56.06
# 8  2019-01-09  George  12.25
# 9  2019-01-10  George  47.41
# 10 2019-01-11  Victor  58.66
# 11 2019-01-12   Lucas  53.35

# %%
df.pivot(index= 'Dia', columns= 'Nome', values= 'Gasto')
# Out:
# Nome        George  Lucas  Victor
# Dia
# 2019-01-01     NaN    NaN    1.99
# 2019-01-02     NaN  99.00     NaN
# 2019-01-03    8.83    NaN     NaN
# 2019-01-04     NaN  41.42     NaN
# 2019-01-05     NaN    NaN   87.34
# 2019-01-06   18.51    NaN     NaN
# 2019-01-07     NaN   3.56     NaN
# 2019-01-08   56.06    NaN     NaN
# 2019-01-09   12.25    NaN     NaN
# 2019-01-10   47.41    NaN     NaN
# 2019-01-11     NaN    NaN   58.66
# 2019-01-12     NaN  53.35     NaN
