# %%
import pandas as pd
import numpy as np

# %%
datas = pd.date_range('20190101', periods = 60, freq='D')
df = pd.DataFrame(np.random.randn(60,5), index = datas, columns = list ('ABCDE'))

# %%
df.shape
# Out:
# (60, 5)

# %%
df.head(3)
# Out:
#                    A         B         C         D         E
# 2019-01-01 -0.273585  0.312542  0.347300  1.581474  0.515934
# 2019-01-02  0.495354  0.830535 -1.367704 -0.503197  0.225397
# 2019-01-03 -1.630740 -0.070219 -0.280892 -0.686896  1.813817

# %%
df['F'] = 1

# %%
df.head(3)
# Out:
#                    A         B         C         D         E  F
# 2019-01-01 -0.273585  0.312542  0.347300  1.581474  0.515934  1
# 2019-01-02  0.495354  0.830535 -1.367704 -0.503197  0.225397  1
# 2019-01-03 -1.630740 -0.070219 -0.280892 -0.686896  1.813817  1

# %%
df['G'] = range(60)

# %%
df.head(10)
# Out:
#                    A         B         C         D         E  F  G
# 2019-01-01 -0.273585  0.312542  0.347300  1.581474  0.515934  1  0
# 2019-01-02  0.495354  0.830535 -1.367704 -0.503197  0.225397  1  1
# 2019-01-03 -1.630740 -0.070219 -0.280892 -0.686896  1.813817  1  2
# 2019-01-04  0.575775 -0.173595 -0.154174 -1.785133 -0.079641  1  3
# 2019-01-05  0.451209  0.522250  0.241659 -0.436438  0.810920  1  4
# 2019-01-06  0.282912 -1.148337  0.025925 -0.019457  0.599339  1  5
# 2019-01-07 -0.915811 -0.640885  1.933326 -0.755607 -0.434868  1  6
# 2019-01-08 -1.330840  0.095557  0.697625 -1.966120  0.564854  1  7
# 2019-01-09 -0.115661  1.141445 -2.791136 -0.325362 -0.864656  1  8
# 2019-01-10  0.403785 -0.369855  0.049337 -1.237842  0.620804  1  9

# %%
df['Produto'] = df['A'] * df['B']

# %%
df.head(3)
# Out:
#                    A         B         C         D         E  F  G   Produto
# 2019-01-01 -0.273585  0.312542  0.347300  1.581474  0.515934  1  0 -0.085507
# 2019-01-02  0.495354  0.830535 -1.367704 -0.503197  0.225397  1  1  0.411409
# 2019-01-03 -1.630740 -0.070219 -0.280892 -0.686896  1.813817  1  2  0.114509

# %%
df['D'] = 88
df.head(10)
# Out:
#                    A         B         C   D         E  F  G   Produto
# 2019-01-01 -0.273585  0.312542  0.347300  88  0.515934  1  0 -0.085507
# 2019-01-02  0.495354  0.830535 -1.367704  88  0.225397  1  1  0.411409
# 2019-01-03 -1.630740 -0.070219 -0.280892  88  1.813817  1  2  0.114509
# 2019-01-04  0.575775 -0.173595 -0.154174  88 -0.079641  1  3 -0.099952
# 2019-01-05  0.451209  0.522250  0.241659  88  0.810920  1  4  0.235644
# 2019-01-06  0.282912 -1.148337  0.025925  88  0.599339  1  5 -0.324878
# 2019-01-07 -0.915811 -0.640885  1.933326  88 -0.434868  1  6  0.586930
# 2019-01-08 -1.330840  0.095557  0.697625  88  0.564854  1  7 -0.127171
# 2019-01-09 -0.115661  1.141445 -2.791136  88 -0.864656  1  8 -0.132021
# 2019-01-10  0.403785 -0.369855  0.049337  88  0.620804  1  9 -0.149342

# %%
df.tail(2)
# Out:
#                    A         B         C   D         E  F   G   Produto
# 2019-02-28  1.326860  1.051414  0.816632  88  0.143176  1  58  1.395079
# 2019-03-01  0.510575  0.664279 -1.777305  88 -0.508011  1  59  0.339165
