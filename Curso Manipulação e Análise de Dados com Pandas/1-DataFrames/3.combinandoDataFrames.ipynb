# %%
import pandas as pd

# %%
df1 = pd.DataFrame({'A' : ['AO', 'A1', 'A2', 'A3'],
                    'B' : ['B0', 'B1', 'B2', 'B3'],
                    'C' : ['C0', 'C1', 'C2', 'C3'],
                    'D' : ['D0', 'D1', 'D2', 'D3']},
                   index = [0, 1, 2, 2])

# %%
df2 = pd.DataFrame({'A' : ['A4', 'A5', 'A6', 'A7'],
                    'B' : ['B4', 'B5', 'B6', 'B7'],
                    'C' : ['C4', 'C5', 'C6', 'C7'],
                    'D' : ['D4', 'D5', 'D6', 'D73']},
                   index = [4, 5, 6, 7])

# %%
df3 = pd.DataFrame({'A' : ['A8', 'A9', 'A10', 'A11'],
                    'B' : ['B8', 'B9', 'B10', 'B11'],
                    'C' : ['C8', 'C9', 'C10', 'C11'],
                    'D' : ['D8', 'D9', 'D10', 'D11']},
                   index = [8, 9, 10, 11])

# %%
df1
# Out:
#     A   B   C   D
# 0  AO  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 2  A3  B3  C3  D3

# %%
df2
# Out:
#     A   B   C    D
# 4  A4  B4  C4   D4
# 5  A5  B5  C5   D5
# 6  A6  B6  C6   D6
# 7  A7  B7  C7  D73

# %%
df3
# Out:
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
frames = [df1, df2, df3]
frames
# Out:
# [    A   B   C   D
#  0  AO  B0  C0  D0
#  1  A1  B1  C1  D1
#  2  A2  B2  C2  D2
#  2  A3  B3  C3  D3,     A   B   C    D
#  4  A4  B4  C4   D4
#  5  A5  B5  C5   D5
#  6  A6  B6  C6   D6
#  7  A7  B7  C7  D73,       A    B    C    D
#  8    A8   B8   C8   D8
#  9    A9   B9   C9   D9
#  10  A10  B10  C10  D10
#  11  A11  B11  C11  D11]

# %%
type(frames)
# Out:
# list

# %%
framesCombinados = pd.concat(frames)
framesCombinados
# Out:
#       A    B    C    D
# 0    AO   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 2    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7  D73
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
type(framesCombinados)
# Out:
# pandas.core.frame.DataFrame

# %%
framesCombinados2 = pd.concat([df1, df2, df3])
framesCombinados2
# Out:
#       A    B    C    D
# 0    AO   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 2    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7  D73
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
grupo = pd.concat([df1, df2, df3], keys = ['f1', 'f2', 'f3'])
grupo
# Out:
#          A    B    C    D
# f1 0    AO   B0   C0   D0
#    1    A1   B1   C1   D1
#    2    A2   B2   C2   D2
#    2    A3   B3   C3   D3
# f2 4    A4   B4   C4   D4
#    5    A5   B5   C5   D5
#    6    A6   B6   C6   D6
#    7    A7   B7   C7  D73
# f3 8    A8   B8   C8   D8
#    9    A9   B9   C9   D9
#    10  A10  B10  C10  D10
#    11  A11  B11  C11  D11

# %%
grupo.loc['f2']
# Out:
#     A   B   C    D
# 4  A4  B4  C4   D4
# 5  A5  B5  C5   D5
# 6  A6  B6  C6   D6
# 7  A7  B7  C7  D73

# %%
# Outra Maneira de concatenar

# %%
g2 = df1.append([df2,df3])

# %%
g2
# Out:
#       A    B    C    D
# 0    AO   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 2    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7  D73
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
   g4 = df1.append(df2).apend(df3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-abaa0bd84e3f> in <module>()
# ----> 1 g4 = df1.append(df2).apend(df3)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5139             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5140                 return self[name]
# -> 5141             return object.__getattribute__(self, name)
#    5142
#    5143     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'apend'
