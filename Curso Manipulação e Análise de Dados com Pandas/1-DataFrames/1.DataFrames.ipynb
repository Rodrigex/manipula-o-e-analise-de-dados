# %%
import pandas as pd
import numpy as np

# %%
series = pd.Series([7, 4, np.nan, 6,9])

# %%
series
# Out:
# 0    7.0
# 1    4.0
# 2    NaN
# 3    6.0
# 4    9.0
# dtype: float64

# %%
type(series)
# Out:
# pandas.core.series.Series

# %%
datas = pd.date_range('20180101', periods = 6, freq='D' )

# %%
datas
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04',
#                '2018-01-05', '2018-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
type(datas)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
df = pd.DataFrame(np.random.randn(6,4), index = datas, columns = ['Carros', 'Marcas', 'Pais', 'Modelos']) #list('ABCD')

# %%
np.random.randn(6,4)
# Out:
# array([[ 0.17519811,  0.16889966, -0.26839222,  0.06972697],
#        [ 0.77193454, -0.75101878,  1.36486771, -0.97514489],
#        [-0.87795845, -1.13592147, -0.76012927, -2.16439106],
#        [-2.00900475,  1.02367011,  0.05031704,  1.13708434],
#        [ 0.30703099, -1.31914067,  0.81085736,  1.29840932],
#        [-1.13517917, -0.4573462 ,  0.23756023,  0.93632803]])

# %%
df
# Out:
#               Carros    Marcas      Pais   Modelos
# 2018-01-01  0.979863 -1.045361 -0.481924 -0.438829
# 2018-01-02  0.982156 -1.481711  0.744819  1.071828
# 2018-01-03  1.283764 -0.068220  1.008533 -0.973716
# 2018-01-04  1.365924  0.365656 -0.381978  1.693463
# 2018-01-05 -0.996223  0.076251  2.921545  0.069403
# 2018-01-06  0.465164  0.007978  0.712431 -0.520031

# %%
 df2 = pd.DataFrame({"A":7,
                     'B': pd.Timestamp('20190101'),
                     'C': pd.Series(1, index=list(range(4)), dtype='float32'),
                     'D': np.array([3] * 4, dtype='int32'),
                     'E': pd.Categorical(['test', 'train', 'test', 'train']),
                     'F': 'Python'})

# %%
df2
# Out:
#    A          B    C  D      E       F
# 0  7 2019-01-01  1.0  3   test  Python
# 1  7 2019-01-01  1.0  3  train  Python
# 2  7 2019-01-01  1.0  3   test  Python
# 3  7 2019-01-01  1.0  3  train  Python

# %%
df2.dtypes
# Out:
# A             int64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df.tail(2)
# Out:
#               Carros    Marcas      Pais   Modelos
# 2018-01-05 -0.996223  0.076251  2.921545  0.069403
# 2018-01-06  0.465164  0.007978  0.712431 -0.520031

# %%
df.index
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04',
#                '2018-01-05', '2018-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['Carros', 'Marcas', 'Pais', 'Modelos'], dtype='object')

# %%
c = df.columns

# %%
c
# Out:
# Index(['Carros', 'Marcas', 'Pais', 'Modelos'], dtype='object')

# %%
df.to_numpy()
# Out:
# array([[ 0.97986326, -1.04536116, -0.4819238 , -0.43882905],
#        [ 0.98215583, -1.48171117,  0.74481921,  1.07182787],
#        [ 1.28376406, -0.06822014,  1.00853269, -0.97371573],
#        [ 1.36592445,  0.36565614, -0.38197757,  1.693463  ],
#        [-0.99622326,  0.07625126,  2.92154511,  0.06940327],
#        [ 0.46516392,  0.00797763,  0.71243085, -0.52003073]])

# %%
df.T
# Out:
#          2018-01-01  2018-01-02  2018-01-03  2018-01-04  2018-01-05  2018-01-06
# Carros     0.979863    0.982156    1.283764    1.365924   -0.996223    0.465164
# Marcas    -1.045361   -1.481711   -0.068220    0.365656    0.076251    0.007978
# Pais      -0.481924    0.744819    1.008533   -0.381978    2.921545    0.712431
# Modelos   -0.438829    1.071828   -0.973716    1.693463    0.069403   -0.520031

# %%
df2.T
# Out:
#                      0  ...                    3
# A                    7  ...                    7
# B  2019-01-01 00:00:00  ...  2019-01-01 00:00:00
# C                    1  ...                    1
# D                    3  ...                    3
# E                 test  ...                train
# F               Python  ...               Python
#
# [6 rows x 4 columns]
