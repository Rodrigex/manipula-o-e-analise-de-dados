# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({'A' : ['verdadeiro', 'falso', 'verdadeiro', 'falso', 
                          'verdadeiro', 'falso', 'verdadeiro', 'falso'],
                   'B' : ['um', 'um', 'dois', 'tres',
                          'dois', 'dois', 'um', 'tres'],
                   'C' : np.random.randn(8),
                   'D' : np.random.randn(8)})

# %%
df
# Out:
#             A     B         C         D
# 0  verdadeiro    um  0.520754 -0.712029
# 1       falso    um -1.546246 -0.852497
# 2  verdadeiro  dois  0.246176  0.225937
# 3       falso  tres -1.495070 -0.846123
# 4  verdadeiro  dois  0.258231 -0.889442
# 5       falso  dois  2.605309  1.082189
# 6  verdadeiro    um -0.594054 -2.036650
# 7       falso  tres -0.070827  0.549560

# %%
df.groupby(['A']).sum()
# Out:
#                    C         D
# A
# falso      -0.506834 -0.066871
# verdadeiro  0.431107 -3.412183

# %%
df.groupby(['A']).mean()
# Out:
#                    C         D
# A
# falso      -0.126709 -0.016718
# verdadeiro  0.107777 -0.853046

# %%
df.groupby(['B']).sum()
# Out:
#              C         D
# B
# dois  3.109716  0.418684
# tres -1.565897 -0.296563
# um   -1.619546 -3.601175

# %%
df.groupby(['A', 'B']).sum()
# Out:
#                         C         D
# A          B
# falso      dois  2.605309  1.082189
#            tres -1.565897 -0.296563
#            um   -1.546246 -0.852497
# verdadeiro dois  0.504407 -0.663505
#            um   -0.073300 -2.748678
